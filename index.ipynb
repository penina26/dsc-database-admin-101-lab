# %% [markdown]
# # Database Admin 101 - Lab
#
# ## Introduction
#
# In this lab, you'll go through the process of designing and creating a database. From there, you'll begin to populate this table with mock data provided to you.
#
# ## Objectives
#
# You will be able to:
#
# * Use knowledge of the structure of databases to create a database and populate it

# %% [markdown]
# ## The Scenario
#
# You are looking to design a database for a school that will house various information from student grades to contact information, class roster lists and attendance. First, think of how you would design such a database. What tables would you include? What columns would each table have? What would be the primary means to join said tables?

# %% [markdown]
# ## Creating the Database
#
# Now that you've put a little thought into how you might design your database, it's time to go ahead and create it! Start by import the necessary packages. Then, create a database called **school.sqlite**.

# %%
import sqlite3
import pandas as pd

# %%
# Create the database school.sqlite 
conn = sqlite3.connect('school.sqlite ')
cur = conn.cursor()

# %% [markdown]
# ## Create a Table for Contact Information
#
# Create a table called contactInfo to house contact information for both students and staff. Be sure to include columns for first name, last name, role (student/staff), telephone number, street, city, state, and zipcode. Be sure to also create a primary key for the table.

# %%
cur.execute("""CREATE TABLE contactInfo (
                                id INTEGER PRIMARY KEY,
                                firstName TEXT,
                                lastName TEXT,
                                role TEXT,
                                telephone TEXT,
                                street TEXT,
                                city TEXT,
                                state TEXT,
                                zipcode TEXT )
            """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-affc06e0f4e6> in <module>
# ----> 1 cur.execute("""CREATE TABLE contactInfo (
#       2                                 id INTEGER PRIMARY KEY,
#       3                                 firstName TEXT,
#       4                                 lastName TEXT,
#       5                                 role TEXT,
#
# OperationalError: table contactInfo already exists

# %% [markdown]
# ## Populate the Table
#
# Below, code is provided for you in order to load a list of dictionaries. Briefly examine the list. Each dictionary in the list will serve as an entry for your contact info table. Once you've briefly investigated the structure of this data, write a for loop to iterate through the list and create an entry in your table for each person's contact info.

# %%
# Load the list of dictionaries; just run this cell
import pickle

with open('contact_list.pickle', 'rb') as f:
    contacts = pickle.load(f)
contacts
# Out:
# [{'firstName': 'Christine',
#   'lastName': 'Holden',
#   'role': 'staff',
#   'telephone ': 2035687697,
#   'street': '1672 Whitman Court',
#   'city': 'Stamford',
#   'state': 'CT',
#   'zipcode ': '06995'},
#  {'firstName': 'Christopher',
#   'lastName': 'Warren',
#   'role': 'student',
#   'telephone ': 2175150957,
#   'street': '1935 University Hill Road',
#   'city': 'Champaign',
#   'state': 'IL',
#   'zipcode ': '61938'},
#  {'firstName': 'Linda',
#   'lastName': 'Jacobson',
#   'role': 'staff',
#   'telephone ': 4049446441,
#   'street': '479 Musgrave Street',
#   'city': 'Atlanta',
#   'state': 'GA',
#   'zipcode ': '30303'},
#  {'firstName': 'Andrew',
#   'lastName': 'Stepp',
#   'role': 'student',
#   'telephone ': 7866419252,
#   'street': '2981 Lamberts Branch Road',
#   'city': 'Hialeah',
#   'state': 'Fl',
#   'zipcode ': '33012'},
#  {'firstName': 'Jane',
#   'lastName': 'Evans',
#   'role': 'student',
#   'telephone ': 3259909290,
#   'street': '1461 Briarhill Lane',
#   'city': 'Abilene',
#   'state': 'TX',
#   'zipcode ': '79602'},
#  {'firstName': 'Jane',
#   'lastName': 'Evans',
#   'role': 'student',
#   'telephone ': 3259909290,
#   'street': '1461 Briarhill Lane',
#   'city': 'Abilene',
#   'state': 'TX',
#   'zipcode ': '79602'},
#  {'firstName': 'Mary',
#   'lastName': 'Raines',
#   'role': 'student',
#   'telephone ': 9075772295,
#   'street': '3975 Jerry Toth Drive',
#   'city': 'Ninilchik',
#   'state': 'AK',
#   'zipcode ': '99639'},
#  {'firstName': 'Ed',
#   'lastName': 'Lyman',
#   'role': 'student',
#   'telephone ': 5179695576,
#   'street': '3478 Be Sreet',
#   'city': 'Lansing',
#   'state': 'MI',
#   'zipcode ': '48933'}]

# %%
# Iterate over the contact list and populate the contactInfo table here
values_to_add = []
for contact in contacts:
    values_to_add.append(tuple(contact.values()))        
        
values_to_add

def insertMultipleRecords(recordList):
            q = """INSERT INTO contactInfo
                              (firstName,
                                    lastName,
                                    role,
                                    telephone,
                                    street,
                                    city,
                                    state,
                                    zipcode) 
                              VALUES (?, ?, ?, ?, ?, ?, ?, ?);"""
            cur.executemany(q, recordList)
            
            print("Total", cur.rowcount, "Records inserted successfully into SqliteDb_developers table")
            
            
insertMultipleRecords(values_to_add)
# Out:
# Total 8 Records inserted successfully into SqliteDb_developers table

# %% [markdown]
# **Query the Table to Ensure it is populated**

# %%
# Your code here 
cur.execute('''SELECT * FROM contactInfo; ''').fetchall()
# Out:
# [(1,
#   'Christine',
#   'Holden',
#   'staff',
#   '2035687697',
#   '1672 Whitman Court',
#   'Stamford',
#   'CT',
#   '06995'),
#  (2,
#   'Christopher',
#   'Warren',
#   'student',
#   '2175150957',
#   '1935 University Hill Road',
#   'Champaign',
#   'IL',
#   '61938'),
#  (3,
#   'Linda',
#   'Jacobson',
#   'staff',
#   '4049446441',
#   '479 Musgrave Street',
#   'Atlanta',
#   'GA',
#   '30303'),
#  (4,
#   'Andrew',
#   'Stepp',
#   'student',
#   '7866419252',
#   '2981 Lamberts Branch Road',
#   'Hialeah',
#   'Fl',
#   '33012'),
#  (5,
#   'Jane',
#   'Evans',
#   'student',
#   '3259909290',
#   '1461 Briarhill Lane',
#   'Abilene',
#   'TX',
#   '79602'),
#  (6,
#   'Jane',
#   'Evans',
#   'student',
#   '3259909290',
#   '1461 Briarhill Lane',
#   'Abilene',
#   'TX',
#   '79602'),
#  (7,
#   'Mary',
#   'Raines',
#   'student',
#   '9075772295',
#   '3975 Jerry Toth Drive',
#   'Ninilchik',
#   'AK',
#   '99639'),
#  (8,
#   'Ed',
#   'Lyman',
#   'student',
#   '5179695576',
#   '3478 Be Sreet',
#   'Lansing',
#   'MI',
#   '48933'),
#  (9,
#   'Christine',
#   'Holden',
#   'staff',
#   '2035687697',
#   '1672 Whitman Court',
#   'Stamford',
#   'CT',
#   '06995'),
#  (10,
#   'Christopher',
#   'Warren',
#   'student',
#   '2175150957',
#   '1935 University Hill Road',
#   'Champaign',
#   'IL',
#   '61938'),
#  (11,
#   'Linda',
#   'Jacobson',
#   'staff',
#   '4049446441',
#   '479 Musgrave Street',
#   'Atlanta',
#   'GA',
#   '30303'),
#  (12,
#   'Andrew',
#   'Stepp',
#   'student',
#   '7866419252',
#   '2981 Lamberts Branch Road',
#   'Hialeah',
#   'Fl',
#   '33012'),
#  (13,
#   'Jane',
#   'Evans',
#   'student',
#   '3259909290',
#   '1461 Briarhill Lane',
#   'Abilene',
#   'TX',
#   '79602'),
#  (14,
#   'Jane',
#   'Evans',
#   'student',
#   '3259909290',
#   '1461 Briarhill Lane',
#   'Abilene',
#   'TX',
#   '79602'),
#  (15,
#   'Mary',
#   'Raines',
#   'student',
#   '9075772295',
#   '3975 Jerry Toth Drive',
#   'Ninilchik',
#   'AK',
#   '99639'),
#  (16,
#   'Ed',
#   'Lyman',
#   'student',
#   '5179695576',
#   '3478 Be Sreet',
#   'Lansing',
#   'MI',
#   '48933')]

# %%
pd.read_sql('''SELECT * FROM contactInfo; ''', conn)
# Out:
#     id    firstName  lastName     role   telephone                     street  \
# 0    1    Christine    Holden    staff  2035687697         1672 Whitman Court
# 1    2  Christopher    Warren  student  2175150957  1935 University Hill Road
# 2    3        Linda  Jacobson    staff  4049446441        479 Musgrave Street
# 3    4       Andrew     Stepp  student  7866419252  2981 Lamberts Branch Road
# 4    5         Jane     Evans  student  3259909290        1461 Briarhill Lane
# 5    6         Jane     Evans  student  3259909290        1461 Briarhill Lane
# 6    7         Mary    Raines  student  9075772295      3975 Jerry Toth Drive
# 7    8           Ed     Lyman  student  5179695576              3478 Be Sreet
# 8    9    Christine    Holden    staff  2035687697         1672 Whitman Court
# 9   10  Christopher    Warren  student  2175150957  1935 University Hill Road
# 10  11        Linda  Jacobson    staff  4049446441        479 Musgrave Street
# 11  12       Andrew     Stepp  student  7866419252  2981 Lamberts Branch Road
# 12  13         Jane     Evans  student  3259909290        1461 Briarhill Lane
# 13  14         Jane     Evans  student  3259909290        1461 Briarhill Lane
# 14  15         Mary    Raines  student  9075772295      3975 Jerry Toth Drive
# 15  16           Ed     Lyman  student  5179695576              3478 Be Sreet
#
#          city state zipcode
# 0    Stamford    CT   06995
# 1   Champaign    IL   61938
# 2     Atlanta    GA   30303
# 3     Hialeah    Fl   33012
# 4     Abilene    TX   79602
# 5     Abilene    TX   79602
# 6   Ninilchik    AK   99639
# 7     Lansing    MI   48933
# 8    Stamford    CT   06995
# 9   Champaign    IL   61938
# 10    Atlanta    GA   30303
# 11    Hialeah    Fl   33012
# 12    Abilene    TX   79602
# 13    Abilene    TX   79602
# 14  Ninilchik    AK   99639
# 15    Lansing    MI   48933

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Persist your changes by committing them to the database.

# %%
# Your code here
conn.commit()

# %% [markdown]
# ## Create a Table for Student Grades
#
# Create a new table in the database called "grades". In the table, include the following fields: userId, courseId, grade.
#
# ** This problem is a bit more tricky and will require a dual key. (A nuance you have yet to see.)
# Here's how to do that:
#
# ```SQL
# CREATE TABLE table_name(
#    column_1 INTEGER NOT NULL,
#    column_2 INTEGER NOT NULL,
#    ...
#    PRIMARY KEY(column_1,column_2,...)
# );
# ```

# %%
# Create the grades table
cur.execute('''CREATE TABLE grades(
    userId INTEGER NOT NULL,
    courseId INTEGER NOT NULL,
    grade TEXT,    
    PRIMARY KEY(userId, courseId)
);''')

# %% [markdown]
# ## Remove Duplicate Entries
#
# An analyst just realized that there is a duplicate entry in the contactInfo table! Find and remove it.

# %%
query = ('''SELECT *, COUNT(*) AS num_duplicates
            FROM contactInfo
            GROUP BY firstName, lastName, telephone
            HAVING num_duplicates>1;''')
pd.read_sql(query,conn)
# Out:
#    id    firstName  lastName     role   telephone                     street  \
# 0   4       Andrew     Stepp  student  7866419252  2981 Lamberts Branch Road
# 1   1    Christine    Holden    staff  2035687697         1672 Whitman Court
# 2   2  Christopher    Warren  student  2175150957  1935 University Hill Road
# 3   8           Ed     Lyman  student  5179695576              3478 Be Sreet
# 4   5         Jane     Evans  student  3259909290        1461 Briarhill Lane
# 5   3        Linda  Jacobson    staff  4049446441        479 Musgrave Street
# 6   7         Mary    Raines  student  9075772295      3975 Jerry Toth Drive
#
#         city state zipcode  num_duplicates
# 0    Hialeah    Fl   33012               2
# 1   Stamford    CT   06995               2
# 2  Champaign    IL   61938               2
# 3    Lansing    MI   48933               2
# 4    Abilene    TX   79602               4
# 5    Atlanta    GA   30303               2
# 6  Ninilchik    AK   99639               2

# %%
# Delete the duplicate entry
query = (''' DELETE FROM contactInfo WHERE COUNT(telephone)>1;''')               
            
pd.read_sql(query,conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: misuse of aggregate function COUNT()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-13-84bb696182bb> in <module>
#       2 query = (''' DELETE FROM contactInfo WHERE COUNT(telephone)>1;''')
#       3
# ----> 4 pd.read_sql(query,conn)
#       5
#
# C:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# C:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# C:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql ' DELETE FROM contactInfo WHERE COUNT(telephone)>1;': misuse of aggregate function COUNT()

# %%
# Check that the duplicate entry was removed

# %% [markdown]
# ## Updating an Address
#
# Ed Lyman just moved to `2910 Simpson Avenue York, PA 17403`. Update his address accordingly.

# %%
# Update Ed's address
cur.execute('''UPDATE contactInfo
            SET street ='2910 Simpson Avenue York', state='PA', zipcode='17403'
            WHERE (firstName ='Ed') and( lastName=='Lyman');
            ''')

# %%
# Query the database to ensure the change was made
pd.read_sql('''SELECT * FROM  contactInfo 
                    WHERE  (firstName ='Ed') and( lastName=='Lyman');''', conn)
# Out:
#    id firstName lastName     role   telephone         street     city state  \
# 0   8        Ed    Lyman  student  5179695576  3478 Be Sreet  Lansing    MI
# 1  16        Ed    Lyman  student  5179695576  3478 Be Sreet  Lansing    MI
#
#   zipcode
# 0   48933
# 1   48933

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Once again, persist your changes by committing them to the database.

# %%
conn.commit()

# %% [markdown]
# ## Summary
#
# While there's certainly more to do with setting up and managing this database, you got a taste for creating, populating, and maintaining databases! Feel free to continue fleshing out this exercise for more practice.
